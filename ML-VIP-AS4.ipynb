# %%
import re
from pdfminer.high_level import extract_pages, extract_text
import pandas as pd

# %% [markdown]
# Methods for scraping the articles

# %%
def get_text_pdf(pdfname):
    text = extract_text(pdfname)
    return text

def get_sentences(text):
    pattern = r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?|\!)\s'
    sentences = re.split(pattern, text)
    sentences = [s.strip() for s in sentences if s.strip()]
    return sentences

def display_sentences(list):
    for sentence in list:
        print(sentence + "\n")
        print("--------------------------------------")

def dictionary_to_df(sentences):
    return pd.DataFrame(sentences, columns=['Sentence'])

def save_dataframe(df, filename):
    try:
        df.to_csv(filename)
        print("save successful")
    except:
        print("file not saved properly")

# %%
articles_path = '/Users/prasunbanerjee/Desktop/UniversityMaterials/Research/FSIL/data/bkSamples.csv'

# %%
df = pd.read_csv(articles_path)
df
# Out:
#    Unnamed: 0                     Date  \
# 0    408606.0  2020-03-05 00:00:00 UTC
# 1    410049.0  2023-05-30 00:00:00 UTC
# 2    406317.0  2023-03-01 00:00:00 UTC
# 3    411513.0  2022-06-08 00:00:00 UTC
# 4    414066.0  2016-08-03 00:00:00 UTC
# 5    412597.0  2020-10-21 00:00:00 UTC
# 6    411682.0  2022-04-23 00:00:00 UTC
# 7    411425.0  2022-06-28 00:00:00 UTC
# 8    408086.0  2020-09-18 00:00:00 UTC
# 9    413546.0  2018-09-07 00:00:00 UTC
#
#                                        Article_title Stock_symbol  \
# 0  6 Compelling Reasons to Ignore Coronavirus and...          BRK
# 1  For the First Time in 23 Years, the S&P 500 Is...          BRK
# 2  Warren Buffett vs. Cathie Wood: Where Would Yo...          BRK
# 3                      Why Tesla Stock Bounced Today          BRK
# 4      Head to Head: Donald Trump and Warren Buffett          BRK
# 5  Berkshire Hathaway Stock Is Telling Investors ...          BRK
# 6  This Was the Biggest Software IPO Ever, and th...          BRK
# 7  Got $1,000? 3 Buffett Stocks to Buy Now and Ho...          BRK
# 8  Validea Peter Lynch Strategy Daily Upgrade Rep...          BRK
# 9                  Bitcoin: Is This the End of Rico?          BRK
#
#                                                  Url  Publisher  Author  \
# 0  https://www.nasdaq.com/articles/6-compelling-r...        NaN     NaN
# 1  https://www.nasdaq.com/articles/for-the-first-...        NaN     NaN
# 2  https://www.nasdaq.com/articles/warren-buffett...        NaN     NaN
# 3  https://www.nasdaq.com/articles/why-tesla-stoc...        NaN     NaN
# 4  https://www.nasdaq.com/articles/head-head-dona...        NaN     NaN
# 5  https://www.nasdaq.com/articles/berkshire-hath...        NaN     NaN
# 6  https://www.nasdaq.com/articles/this-was-the-b...        NaN     NaN
# 7  https://www.nasdaq.com/articles/got-%241000-3-...        NaN     NaN
# 8  https://www.nasdaq.com/articles/validea-peter-...        NaN     NaN
# 9  https://www.nasdaq.com/articles/bitcoin-end-ri...        NaN     NaN
#
#                                              Article  \
# 0  Investors have been inundated with headlines a...
# 1  Regardless of how long you've been investing, ...
# 2  Cathie Wood went from the hottest investing gu...
# 3  What happened\nShares of Tesla (NASDAQ: TSLA) ...
# 4  On Monday afternoon, universally recognized in...
# 5  InvestorPlace - Stock Market News, Stock Advic...
# 6  Snowflake's (NYSE: SNOW) expanding margins and...
# 7  Investors from all walks of life idolize Warre...
# 8  The following are today's upgrades for Validea...
# 9  InvestorPlace - Stock Market News, Stock Advic...
#
#                                          Lsa_summary  \
# 0  Buffett owns a massive stake Berkshire Hathawa...
# 1  The nine largest components of the S&P 500 (in...
# 2  However, Wood's Ark Innovation ETF is running ...
# 3  What happened Shares of Tesla (NASDAQ: TSLA) a...
# 4  On Monday afternoon, universally recognized in...
# 5  InvestorPlace - Stock Market News, Stock Advic...
# 6  Early investors were Berkshire Hathaway (NYSE:...
# 7  The remaining sales came from consumer health ...
# 8  BERKSHIRE HATHAWAY INC. (BRK.A) is a large-cap...
# 9  That gives bitcoin a market cap of $111 billio...
#
#                                         Luhn_summary  \
# 0  Buffett owns a massive stake Berkshire Hathawa...
# 1  The nine largest components of the S&P 500 (in...
# 2  However, Wood's Ark Innovation ETF is running ...
# 3  After all, the newsletter they have run for ov...
# 4  On Monday afternoon, universally recognized in...
# 5  InvestorPlace - Stock Market News, Stock Advic...
# 6  Early investors were Berkshire Hathaway (NYSE:...
# 7  A no-brainer Buffett cash cow stock to buy Vis...
# 8  Detailed Analysis of BERKSHIRE HATHAWAY INC. F...
# 9  That gives bitcoin a market cap of $111 billio...
#
#                                     Textrank_summary  \
# 0  Buffett owns a massive stake Berkshire Hathawa...
# 1  The nine largest components of the S&P 500 (in...
# 2  However, Wood's Ark Innovation ETF is running ...
# 3  The report quoted BYD Vice President Lian Yubo...
# 4  On Monday afternoon, universally recognized in...
# 5  InvestorPlace - Stock Market News, Stock Advic...
# 6  Early investors were Berkshire Hathaway (NYSE:...
# 7  Buffett saw promise in this stock when no one ...
# 8  BERKSHIRE HATHAWAY INC. (BRK.A) is a large-cap...
# 9  That gives bitcoin a market cap of $111 billio...
#
#                                      Lexrank_summary
# 0  Buffett owns a massive stake Berkshire Hathawa...
# 1  The nine largest components of the S&P 500 (in...
# 2  However, Wood's Ark Innovation ETF is running ...
# 3  Buffett's Berkshire Hathaway owned 225 million...
# 4  On Monday afternoon, universally recognized in...
# 5  InvestorPlace - Stock Market News, Stock Advic...
# 6  Early investors were Berkshire Hathaway (NYSE:...
# 7  His company, Berkshire Hathaway, owns more tha...
# 8  BERKSHIRE HATHAWAY INC. (BRK.A) is a large-cap...
# 9  That gives bitcoin a market cap of $111 billio...

# %%
#constructing the dataframes from each article
def split_articles(df):
    return df['Article'].apply(get_sentences).tolist()

def sentences_to_df(data):
    all_rows = []
    for idx, sentences in enumerate(data):
        for sentence in sentences:
            all_rows.append({'Article_ID': idx + 1, 'Sentence': sentence})
    
    return pd.DataFrame(all_rows)

# %%
sentences_list = split_articles(df)
df_sentences = sentences_to_df(sentences_list)
df_sentences
# Out:
#      Article_ID                                           Sentence
# 0             1  Investors have been inundated with headlines a...
# 1             1  The Dow Jones Industrial Average, the S&P 500,...
# 2             1  Famed investor Warren Buffett has counseled in...
# 3             1  Be greedy when others are fearful." With that ...
# 4             1                               Image source: Apple.
# ..          ...                                                ...
# 433          10       As of this writing, he owned shares in BABA.
# 434          10  To follow the value of cryptocurrencies bookma...
# 435          10                  appeared first on InvestorPlace .
# 436          10  The views and opinions expressed herein are th...
# 437          10  The views and opinions expressed herein are th...
#
# [438 rows x 2 columns]

# %%
df_sentences.to_csv('BKRSentences.csv', index=False)
